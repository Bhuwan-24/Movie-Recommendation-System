# %% [markdown]
# Required imports

# %%
from datasets import load_dataset
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy.sparse as sp
import numpy as np

# %% [raw]
# Loading Dataset into pandas dataframe

# %%
ds = load_dataset("milistu/AMAZON-Products-2023")
x_train=pd.DataFrame(ds['train'].select_columns(['title', 'description', 'main_category']))
x_train.head()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#                                                title  \
# 0                                  Anomie & Bonhomie
# 1  Sunshine On My Shoulders: The Best Of John Den...
# 2                     18 Greatest Hits of 38 Special
# 3                                      The Gift [CD]
# 4  ΤΗΕ ΒΟΟΤLΕG SΕRΙΕS VοΙ. ᛐ7 ᛐ996-ᛐ997 FRΑԌΜΕΝΤՏ...
#
#                                          description  main_category
# 0  Amazon.com\nFans of Scritti Politti's synth-po...  Digital Music
# 1  “Sunshine On My Shoulders” is a 2CD, 36-track ...  Digital Music
# 2  Track Listings:  1. Rockin' Into The Night 2. ...  Digital Music
# 3  Second studio album by the multi-million-selli...  Digital Music
# 4  EU Edition 2CD,\nDISC ONE - TIME OUT OF MIND [...  Digital Music

# %%
print(f"The number of rows and columns are : {x_train.shape}")
print(f"There are {x_train['main_category'].nunique()} unique categories")
print(f"\nNull values\n{x_train.isnull().sum()}")
# Out:
# The number of rows and columns are : (117243, 3)
# There are 37 unique categories
#
# Null values
# title                0
# description          0
# main_category    24805
# dtype: int64

# %%
print(f"\n{x_train['main_category'].value_counts().head(20)}")
# Out:
# main_category
# AMAZON FASHION               36460
# Amazon Home                  13874
# Tools & Home Improvement      7945
# Automotive                    5980
# Cell Phones & Accessories     3471
# Health & Personal Care        3416
# All Electronics               3136
# Sports & Outdoors             2942
# Office Products               2925
# Industrial & Scientific       2460
# Pet Supplies                  1907
# Computers                     1724
# Digital Music                 1379
# Handmade                      1127
# Arts, Crafts & Sewing          874
# Camera & Photo                 842
# Musical Instruments            506
# Appliances                     312
# Home Audio & Theater           218
# Video Games                    182
# Name: count, dtype: int64

# %%
print(f"\n{x_train['main_category'].value_counts().tail(18)}")
# Out:
# main_category
# Video Games                     182
# Toys & Games                    146
# Appstore for Android            142
# Collectibles & Fine Art         114
# Car Electronics                  69
# All Beauty                       65
# GPS & Navigation                 54
# Portable Audio & Accessories     32
# Collectible Coins                31
# Grocery                          24
# Baby                             23
# Sports Collectibles              21
# Software                         12
# Entertainment                    11
# Gift Cards                        8
# Magazine Subscriptions            3
# Amazon Devices                    2
# Amazon Fire TV                    1
# Name: count, dtype: int64

# %%
cleaned_df=pd.read_csv('clean_data.csv')
cleaned_df.head()
# Out:
#                                                title  \
# 0                                    anomie bonhomie
# 1  sunshine on my shoulder the best of john denve...
# 2                      18 greatest hit of 38 special
# 3                                        the gift cd
# 4  τηε βοοτlεg sεrιεs vοι ᛐ7 ᛐ996ᛐ997 frαԍμεντտ τ...
#
#                                          description  main_category
# 0  amazoncom fan of scritti polittis synthpopfunk...  digital music
# 1  sunshine on my shoulder be a 2cd 36track colle...  digital music
# 2  track listings 1 rockin into the night 2 hold ...  digital music
# 3  second studio album by the multimillionselling...  digital music
# 4  eu edition 2cd disc one time out of mind 2022 ...  digital music

# %%
cleaned_df['main_category'].value_counts().tail(20)
# Out:
# main_category
# all electronics            4289
# office products            3222
# industrial & scientific    2992
# pet supplies               2693
# computers                  2304
# handmade                   1959
# digital music              1420
# arts, crafts & sewing      1314
# camera & photo              895
# musical instruments         533
# appliances                  434
# video games                 251
# home audio & theater        234
# other                       203
# toys & games                186
# appstore for android        147
# collectibles & fine art     116
# all beauty                   84
# car electronics              74
# gps & navigation             60
# Name: count, dtype: int64

# %%
print(cleaned_df.isnull().sum())
cleaned_df=cleaned_df.dropna()
# Out:
# title             6
# description      70
# main_category     0
# dtype: int64

# %%
cleaned_df.isna().sum()
# Out:
# title            0
# description      0
# main_category    0
# dtype: int64

# %%
t_tfidf=TfidfVectorizer(max_features=25000, ngram_range=(1,2), stop_words='english')
c_tfidf=TfidfVectorizer(max_features=1000,stop_words='english')
d_tfidf=TfidfVectorizer(max_features=25000,ngram_range=(1,2),stop_words='english')

# %%
t_vector=t_tfidf.fit_transform(cleaned_df['title'])
c_vector=t_tfidf.fit_transform(cleaned_df['main_category'])
d_vector=d_tfidf.fit_transform(cleaned_df['description'])

# %%
tw=3.0
cw=2.0
dw=1.0

# %%
t_vector=t_vector*tw
c_vector=c_vector*cw
d_vector=d_vector*dw

# %%
s_v=sp.hstack([t_vector,c_vector,d_vector],format='csr')

# %%
def rcmd(product_name):
    p_vector=tfidf.transform(product_name)
    similarity=cosine_similarity(p_vector,s_v)

# %%
similarity=cosine_similarity(np.array()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 similarity=cosine_similarity(np.array([0.2,0.19,0,0,0.88,0.89]).reshape(-1,1),s_v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\pairwise.py:1741, in cosine_similarity(X, Y, dense_output)
#    1695 """Compute cosine similarity between samples in X and Y.
#    1696
#    1697 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)   1737        [0.57..., 0.81...]])
#    1738 """
#    1739 # to avoid recursive import
# -> 1741 X, Y = check_pairwise_arrays(X, Y)
#    1743 X_normalized = normalize(X, copy=True)
#    1744 if X is Y:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\pairwise.py:229, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, ensure_all_finite, ensure_2d, copy)
#     221         raise ValueError(
#     222             "Precomputed metric requires shape "
#     223             "(n_queries, n_indexed). Got (%d, %d) "
#     224             "for %d indexed." % (X.shape[0], X.shape[1], Y.shape[0])
#     225         )
#     226 elif ensure_2d and X.shape[1] != Y.shape[1]:
#     227     # Only check the number of features if 2d arrays are enforced. Otherwise,
#     228     # validation is left to the user for custom metrics.
# --> 229     raise ValueError(
#     230         "Incompatible dimension for X and Y matrices: "
#     231         "X.shape[1] == %d while Y.shape[1] == %d" % (X.shape[1], Y.shape[1])
#     232     )
#     234 return X, Y
#
# ValueError: Incompatible dimension for X and Y matrices: X.shape[1] == 1 while Y.shape[1] == 50073

# %%
# Out:
# array([375, 163, 290, 224, 268])
